# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
import csv
df = pd.read_csv(r'wines.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           4            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality wine_color
# ...

# %%
df.sort_values(by='quality',ascending = False)
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 2475         876            6.9             0.360         0.34
# 3204        1605            7.1             0.260         0.49
# 2426         827            7.4             0.240         0.36
# 2373         774            9.1             0.270         0.45
# 2419         820            6.6             0.360         0.29
# ...          ...            ...               ...          ...
# 3649        2050           11.8             0.230         0.38
# 1374        1374            6.8             0.815         0.00
# 4906        3307            9.4             0.240         0.29
# 1299        1299            7.6             1.580         0.00
# 1469        1469            7.3             0.980         0.05
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 2475             4.2      0.018                 57.0                 119.0
# ...

# %%
df.sort_values(by='total sulfur dioxide',ascending = False)
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 6344        4745            6.1             0.260         0.25
# 3016        1417            8.6             0.550         0.35
# 3726        2127            9.1             0.330         0.38
# 1924         325            7.5             0.270         0.31
# 3530        1931            7.1             0.490         0.22
# ...          ...            ...               ...          ...
# 1287        1287            8.0             0.600         0.08
# 986          986            9.8             0.340         0.39
# 979          979           12.2             0.450         0.49
# 984          984           12.2             0.450         0.49
# 915          915            8.6             0.315         0.40
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 6344            2.90      0.047                289.0                 440.0
# ...

# %%
df.sort_values(by='free sulfur dioxide',ascending = False)
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 6344        4745            6.1             0.260         0.25
# 3530        1931            7.1             0.490         0.22
# 4649        3050            6.2             0.255         0.24
# 1924         325            7.5             0.270         0.31
# 3933        2334            7.5             0.230         0.35
# ...          ...            ...               ...          ...
# 774          774            7.9             0.400         0.30
# 5267        3668            6.5             0.270         0.26
# 530          530            9.1             0.220         0.24
# 535          535            9.1             0.220         0.24
# 773          773            7.9             0.400         0.29
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 6344             2.9      0.047                289.0                 440.0
# ...

# %%
df.sort_values(by='sulphates',ascending = False)
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 151          151            9.2             0.520         1.00
# 92            92            8.6             0.490         0.29
# 86            86            8.6             0.490         0.28
# 91            91            8.6             0.490         0.28
# 723          723            7.1             0.310         0.30
# ...          ...            ...               ...          ...
# 5127        3528            6.9             0.750         0.13
# 2809        1210            9.2             0.280         0.41
# 2725        1126            6.5             0.115         0.29
# 4883        3284            8.0             0.340         0.25
# 4843        3244            6.7             0.210         0.36
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 151             3.40      0.610                 32.0                  69.0
# ...

# %%
sns.barplot(data=df, x=df.quality, y=df['total sulfur dioxide'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
sns.barplot(data=df, x=df.quality, y=df['sulphates'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
sns.barplot(data=df, x=df.quality, y=df['chlorides'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
sns.barplot(data=df, x=df.quality, y=df['alcohol'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.barplot(data=df, x=df.quality, y=df['residual sugar'], hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
sns.barplot(data=df, x=df.quality, y=df['citric acid'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
sns.barplot(data=df, x=df.quality, y=df['volatile acidity'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(data=df, x=df.quality, y=df['fixed acidity'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
sns.barplot(data=df, x=df.quality, y=df['pH'],hue = df.wine_color)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>
